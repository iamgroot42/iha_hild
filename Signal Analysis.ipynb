# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
plt.rcParams['font.family'] = 'Times New Roman'

# %%
z = np.load("signals_adv_untarg_apgd.npy", allow_pickle=True).item()

# %%
signals_in = z['in']
signals_out = z['out']

# %%
# signals_in = np.expand_dims(signals_in, 1)
# signals_out = np.expand_dims(signals_out, 1)

# %%
plt.hist(signals_in[:, 0], alpha=0.75, label="in", bins=50)
plt.hist(signals_out[:, 0], alpha=0.75, label="out", bins=50)
plt.legend()

# %%
plt.plot(np.sort(signals_in[:, 1]), label="in", linestyle='', marker='.')
plt.plot(np.sort(signals_out[:, 1])[::-1], label="out", linestyle='', marker='.')
plt.legend()

# %%
plt.clf()
plt.scatter(signals_in[:, 0], signals_in[:, 1] , alpha=0.75, label="in", s=6, marker='x')
plt.scatter(signals_out[:, 0], signals_out[:, 1], alpha=0.75, label="out", s=6, marker='o')
plt.xlabel('Perturbation norm')
plt.ylabel('Loss')
plt.legend()

# %%
def classification_rule(z):
    if z[2] <= 1.2112:
        return 1
    return 0
#     if z[2] > 1 or z[2] > 0.02:
#     if  or z[2] > 1:
#         return 0
    return 1
#     if z[0] > 1:
#         return 0
#     if z[0] > 1 or z[2] < -1:
#         return 0
    return 1

in_pred = np.array([classification_rule(i) for i in signals_in])
out_pred = np.array([classification_rule(i) for i in signals_out])

# %%
(np.sum(out_pred==0) + np.sum(in_pred==1))/1000
# Out:
# 0.515
